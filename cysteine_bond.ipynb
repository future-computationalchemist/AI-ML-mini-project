# %% [markdown]
# <a href="https://colab.research.google.com/github/future-computationalchemist/AI-ML-mini-project/blob/main/cysteine_bond.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-07b6b7d5-354f-4829-800b-f30295d44ee3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07b6b7d5-354f-4829-800b-f30295d44ee3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# CTT2iiiii9.pdb	sample_data

# %%
# !apt-get update -y
# !apt-get install -y openbabel
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [88.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,968 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.0 MB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.8 kB]
# ...

# %%
# !obabel CTT2iiiii9.pdb -O start.xyz
# Out:
# 1 molecule converted

# %%
# !head start.xyz
# Out:
# 149
# CTT2iiiii9.pdb
# N        -60.90300      -27.85600        4.01700
# C        -60.34400      -26.50700        4.01700
# C        -58.83400      -26.54700        4.01700
# O        -58.20500      -27.61500        4.01700
# C        -60.91300      -25.74100        5.22700
# S        -60.40200      -24.00800        5.18500
# H        -60.27500      -28.73500        4.01700
# H        -60.65900      -26.00100        3.08600

# %%
# !wget https://github.com/grimme-lab/xtb/releases/download/v6.6.1/xtb-6.6.1-linux-x86_64.tar.xz
# !tar -xf xtb-6.6.1-linux-x86_64.tar.xz
# Out:
# --2026-04-15 14:10:39--  https://github.com/grimme-lab/xtb/releases/download/v6.6.1/xtb-6.6.1-linux-x86_64.tar.xz
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import os
os.environ["PATH"] += ":/content/xtb-6.6.1/bin"

# %%
# !xtb --version
# Out:
#       -----------------------------------------------------------
#      |                   =====================                   |
#      |                           x T B                           |
#      |                   =====================                   |
#      |                         S. Grimme                         |
#      |          Mulliken Center for Theoretical Chemistry        |
#      |                    University of Bonn                     |
#       -----------------------------------------------------------
#
#    * xtb version 6.6.1 (8d0f1dd) compiled by 'stahn@M-Bot' on 2023-08-01
#
# normal termination of xtb

# %%
# !xtb start.xyz --opt
# Out:
# Streaming output truncated to the last 5000 lines.
# ........................................................................
# .............................. CYCLE   19 ..............................
# ........................................................................
#
#  iter      E             dE          RMSdq      gap      omega  full diag
#    1   -246.8979839 -0.246898E+03  0.251E-01    0.13       0.0  T
#    2   -246.8855919  0.123920E-01  0.409E-01    0.35       1.0  T
#    3   -246.8968466 -0.112547E-01  0.242E-01    0.12       1.0  T
#    4   -246.9002510 -0.340436E-02  0.147E-01    0.21       1.0  T
#    5   -246.9011554 -0.904424E-03  0.787E-02    0.17       1.0  T
#    6   -246.9012130 -0.576237E-04  0.286E-02    0.17       1.0  T
#    7   -246.9012834 -0.703860E-04  0.112E-02    0.16       1.0  T
#    8   -246.9012848 -0.138968E-05  0.459E-03    0.16       1.8  T
#    9   -246.9012852 -0.348284E-06  0.265E-03    0.16       3.1  T
# ...

# %%
# !grep "TOTAL ENERGY" xtbopt.log

# %%
from google.colab import files
files.download("xtbopt.xyz")
files.download("xtbopt.log")
