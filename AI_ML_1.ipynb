# %% [markdown]
# <a href="https://colab.research.google.com/github/future-computationalchemist/AI-ML-mini-project/blob/main/AI_ML_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
water_temp_celsius = 83.5
dissolved_oxygen_mg_l = 10.5
ph_sensor = 4.6
carbondioxide_ppm = 76.0
Secchi_disk_cm =20.5
nitrate_level_mg_l = 89.9

print ("--- Oluwafifehanmi Aquarium Sensor Check---")

if dissolved_oxygen_mg_l < 7.9:
 print("ALERT:Oxygen levels is critcical! activating aeration pump")
elif water_temp_celsius > 78.9:
  print ("WARNING:Temperature is high. Activating cooling system")
elif ph_sensor < 5.8:
  print("ALERT:Low PH level. Activating PH control system")
elif carbondioxide_ppm > 60.0:
  print("EMERGENCY: Carbondidoxide levels is high.Activating emergency control carbondioxide system")
elif Secchi_disk_cm < 30.9:
  print("WARNING:High plankton density,zero level of water clarity! Activate the plankton remover machine")
elif nitrate_level_mg_l < 90.0:
  print("EMERGENCY:Relative non toxic exceed the principal limit.Activating the nitrate level monitoring system")
else:
  print("STATUS:Aquarium level is optimal")
# Out:
# --- Oluwafifehanmi Aquarium Sensor Check---
# WARNING:Temperature is high. Activating cooling system
